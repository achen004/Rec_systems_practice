# %%
import pandas as pd
import numpy as np 
import re
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity 
from sentence_transformers import SentenceTransformer
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from rank_bm25 import BM25Okapi #better version of tfidf
import warnings
warnings.filterwarnings("ignore")

# %%
anime_data=pd.read_csv(r'D:\NYUMSDS_courses\Projects\ConsumerReviewData\imdb_anime.csv', on_bad_lines='skip')

# %%
anime_data.head()
print(anime_data.columns)
print(len(anime_data))
# Out:
# Index(['Title', 'Genre', 'User Rating', 'Number of Votes', 'Runtime', 'Year',
#        'Summary', 'Stars', 'Certificate', 'Metascore', 'Gross', 'Episode',
#        'Episode Title'],
#       dtype='object')
# 45717

# %%
col_select=['Title', 'Summary']
new_df=anime_data[col_select]
new_df['Summary'].fillna('', inplace=True)
new_df['Summary']=new_df['Title']+'. '+new_df['Summary'].map(str)
new_df.dropna(inplace=True)
new_df.drop_duplicates(inplace=True)

# %%
new_df.head()
# Out:
#                                          Title  \
# 0                                    One Piece
# 1  Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                  The Super Mario Bros. Movie
# 3                              Attack on Titan
# 4                               Jujutsu Kaisen
#
#                                              Summary
# 0  One Piece. Follows the adventures of Monkey D....
# 1  Teenage Mutant Ninja Turtles: Mutant Mayhem. T...
# 2  The Super Mario Bros. Movie. A plumber named M...
# 3  Attack on Titan. After his hometown is destroy...
# 4  Jujutsu Kaisen. A boy swallows a cursed talism...

# %%
def movie_search_term(df:pd.DataFrame, title_col:str, term: str):
    df[title_col]=df[title_col].str.lower()
    movies=df[title_col].values
    options=[(i,m) for i,m in enumerate(movies) for word in m.split(' ') if word==term.lower()]
    return options

# %%
df=new_df
title='Title'
term='One'
movie_search_term(df=df, title_col=title, term=term)
# Out:
# [(0, 'one piece'),
#  (44, 'one punch man'),
#  (72, 'one piece film: red'),
#  (197, 'one piece: the movie'),
#  (287, 'one piece: stampede'),
#  (334, 'one piece film: gold'),
#  (337, 'one piece film z'),
#  (456, 'one piece: strong world'),
#  (548, 'one piece: baron omatsuri and the secret island'),
#  (593, 'tenpuru -no one can live on loneliness-'),
#  (664, 'a thousand & one nights'),
#  (693, 'one piece: heart of gold'),
#  (695, 'one piece: clockwork island adventure'),
#  (756, 'one piece: dead end adventure'),
#  (848,
#   "one piece - episode of east blue: luffy and his four friends' great adventure"),
#  (911, 'level 1 demon lord and one room hero'),
#  (1014,
#   'one piece: episode of alabasta - the desert princess and the pirates'),
#  (1016, 'one piece: episode of skypiea'),
#  (1033,
#   'one piece: episode of nami - tears of a navigator and the bonds of friends'),
#  (1060, 'one piece: the cursed holy sword'),
#  (1080, 'one piece: episode of luffy - adventure on hand island'),
#  (1131, "one piece: 3d2y - overcome ace's death! luffy's vow to his friends"),
#  (1136, "one piece: chopper's kingdom in the strange animal island"),
#  (1196, 'one piece: episode of merry - mou hitori no nakama no monogatari'),
#  (1255,
#   'dream 9 toriko x one piece x dragon ball z super collaboration special!!'),
#  (1270, 'are you really the only one who likes me'),
#  (1323, "one piece tv special: adventure in the ocean's navel"),
#  (1334, 'one piece: the giant mechanical soldier of karakuri castle'),
#  (1401, 'one piece film: strong world'),
#  (1462, 'one piece: defeat him! the pirate ganzack!'),
#  (1476,
#   'one piece: episode of chopper plus - bloom in the winter, miracle sakura'),
#  (1540, 'one outs'),
#  (1764, 'one piece 3d: straw hat chase'),
#  (1832, 'cat shit one'),
#  (1896, 'one piece: luffy senpai ouen kikaku! barto no himitsu no heya!'),
#  (2025, 'one piece: adventure of nebulandia'),
#  (2152, 'case closed: episode one - the great detective turned small'),
#  (2166,
#   'one piece: episode of sabo - bond of three brothers, a miraculous reunion and an inherited will'),
#  (2492, 'one piece: dream soccer king!'),
#  (2570, 'one piece: romance dawn story'),
#  (2860, 'one piece: protect! the last great stage'),
#  (2978, 'one room'),
#  (3121, 'one week friends'),
#  (3229, 'one punch man: ova 2 #03 genos to kioku sôshitsu'),
#  (3391, "one piece: jango's dance carnival"),
#  (3529, "one piece: open upon the great sea! a father's huge, huge dream!"),
#  (3568, 'one punch man - wanpanman: bang, who is too overbearing'),
#  (3781, 'one piece: mezase! kaizoku yakyu o'),
#  (4316, 'mobile suit gundam ms igloo: the hidden one year war'),
#  (4606, 'one million-year trip: bandar book'),
#  (4625, 'one stormy night: secret friends'),
#  (5051, 'one arm'),
#  (5415, 'one piece pilot 1'),
#  (5476, 'one piece 3d gekisou! trap coaster'),
#  (5701, 'one punch man: ova 2 #01 saitama to sokosoko no noryokumono-tachi'),
#  (5722, 'one pound gospel'),
#  (5789, 'one piece: promotion reflection'),
#  (6090, 'one punch man: ova 2 #02 ossan-tachi to tsuri'),
#  (6253, 'one punch man - wanpanman: the shadow that snuck up too close'),
#  (6389,
#   'one punch man: ova 2 #05 puri-puri prisoner to datsugoku shûjin-tachi'),
#  (6539,
#   'one piece: otoshidama special - tokubetsu hou mugiwara kaizoku-dan no himitsu!'),
#  (6712, 'the three-eyed one'),
#  (6733, 'the tiny one makes it big'),
#  (7803,
#   'one punch man: ova 2 #06 zombieman satsujin jiken 2 - fubuki no sansô to samugari-tachi'),
#  (8167, 'one piece pilot 2'),
#  (8208, 'one piece pilot 3'),
#  (8314, 'one night, hot springs'),
#  (9374, "super jojo-jojo's one day"),
#  (9746, 'find your one way'),
#  (9772, 'nill point work one'),
#  (9902, 'coolrunnings: one on one'),
#  (9902, 'coolrunnings: one on one'),
#  (9906, 'daft punk: one more time'),
#  (12230, 'one piece'),
#  (12231, 'one piece'),
#  (12232, 'one piece'),
#  (12234, 'one piece'),
#  (12245, 'one piece'),
#  (12252, 'one piece'),
#  (12284, 'one piece'),
#  (12285, 'one piece'),
#  (12286, 'one piece'),
#  (12287, 'one piece'),
#  (12366, 'one piece'),
#  (12367, 'one piece'),
#  (12368, 'one piece'),
#  (12369, 'one piece'),
#  (12370, 'one piece'),
#  (12371, 'one piece'),
#  (12372, 'one piece'),
#  (12384, 'one piece'),
#  (12427, 'one piece'),
#  (12428, 'one piece'),
#  (12429, 'one piece'),
#  (12430, 'one piece'),
#  (12431, 'one piece'),
#  (12432, 'one piece'),
#  (12433, 'one piece'),
#  (12434, 'one piece'),
#  (12435, 'one piece'),
#  (12436, 'one piece'),
#  (24097, 'one piece'),
#  (24098, 'one piece'),
#  (24099, 'one piece'),
#  (24170, 'one piece'),
#  (24179, 'one piece'),
#  (24180, 'one piece'),
#  (24224, 'one piece'),
#  (24288, 'one piece'),
#  (24331, 'one piece'),
#  (24332, 'one piece'),
#  (24334, 'one piece'),
#  (24372, 'one piece'),
#  (24373, 'one piece'),
#  (24374, 'one piece'),
#  (24375, 'one piece'),
#  (24388, 'one piece'),
#  (24389, 'one piece'),
#  (24488, 'one piece'),
#  (24543, 'one piece'),
#  (24544, 'one piece'),
#  (24545, 'one piece'),
#  (24556, 'one piece'),
#  (24557, 'one piece'),
#  (24558, 'one piece'),
#  (24559, 'one piece'),
#  (24597, 'one piece'),
#  (24598, 'one piece'),
#  (24612, 'one piece'),
#  (24637, 'one piece'),
#  (24646, 'one piece'),
#  (24666, 'one piece'),
#  (24667, 'one piece'),
#  (24751, 'one piece'),
#  (24755, 'one piece'),
#  (24756, 'one piece'),
#  (24757, 'one piece'),
#  (24766, 'one piece'),
#  (24816, 'one piece'),
#  (24817, 'one piece'),
#  (24864, 'one piece'),
#  (24867, 'one piece'),
#  (24868, 'one piece'),
#  (24871, 'one piece'),
#  (24924, 'one piece'),
#  (24971, 'one piece'),
#  (24972, 'one piece'),
#  (24973, 'one piece'),
#  (25004, 'one piece'),
#  (25021, 'one piece'),
#  (25022, 'one piece'),
#  (25034, 'one piece'),
#  (25105, 'one piece'),
#  (25106, 'one piece'),
#  (25107, 'one piece'),
#  (25108, 'one piece'),
#  (25164, 'one piece'),
#  (25165, 'one piece'),
#  (25166, 'one piece'),
#  (25167, 'one piece'),
#  (25209, 'one piece'),
#  (25210, 'one piece'),
#  (25216, 'one piece'),
#  (25217, 'one piece'),
#  (25386, 'one piece'),
#  (25387, 'one piece'),
#  (25400, 'one room'),
#  (25448, 'one piece'),
#  (25457, 'one piece'),
#  (25458, 'one piece'),
#  (25462, 'one piece'),
#  (25474, 'one piece'),
#  (25488, 'one piece'),
#  (25496, 'one piece'),
#  (25523, 'one piece'),
#  (25524, 'one piece'),
#  (25558, 'one piece'),
#  (25583, 'one piece'),
#  (25584, 'one piece'),
#  (25598, 'one piece'),
#  (25651, 'one piece'),
#  (25678, 'one piece'),
#  (25717, 'one piece'),
#  (25830, 'one piece'),
#  (25837, 'one piece'),
#  (25838, 'one piece'),
#  (25896, 'one piece'),
#  (25897, 'one piece'),
#  (25922, 'one piece'),
#  (25953, 'one piece'),
#  (25954, 'one piece'),
#  (26037, 'one piece'),
#  (26038, 'one piece'),
#  (26096, 'one piece'),
#  (26099, 'one piece'),
#  (26116, 'one piece'),
#  (26118, 'one piece'),
#  (26121, 'one piece'),
#  (26270, 'one piece'),
#  (26334, 'one piece'),
#  (26363, 'one piece')]

# %%
#pick a movie index
movie_idx=695

# %%
#preprocess context
def normalize(d):
    stopwords=nltk.corpus.stopwords.words('english')
    d=re.sub(r'[^a-zA-Z0-9\s]','',d,re.I|re.A)
    d=d.lower().strip()
    sentence_tokens=nltk.word_tokenize(d)
    full_tokens=[t for t in sentence_tokens if t not in stopwords]
    return ' '.join(full_tokens)

# %%
test_norm=normalize(new_df['Summary'][0])
print(test_norm)
# Out:
# one piece follows adventures monkey luffy pirate crew order find greatest treasure ever left legendary pirate gold roger famous mystery treasure named one piece

# %%
def normalized_corpus(df: pd.DataFrame, descript_col: str, tokens=False):
    max_length=0
    n_corpus=np.vectorize(normalize)
    if tokens:
        norm_corpus=n_corpus(list(df[descript_col])) #normalize each of the descriptions 
        tokenized_corpus=[nltk.word_tokenize(d) for d in norm_corpus]
        if max_length==0:
            max_length=max([len(tok_corp) for tok_corp in tokenized_corpus])
        
        #padding
        padded_tok_corps=pad_sequences(tokenized_corpus, maxlen=max_length, padding='post', dtype=object)
        return np.array(padded_tok_corps)
    else:
        return n_corpus(list(df[descript_col]))

# %%
def tf_idf_features(df: pd.DataFrame, normalized_corpus):
    #include both unigrams and bigrams
    tf_idf=TfidfVectorizer(ngram_range=(1,2), min_df=2)
    tfidf_array=tf_idf.fit_transform(normalized_corpus)
    return tfidf_array

# %%
def vector_cosine_sim(tfidf_array):
    return pd.DataFrame(cosine_similarity(tfidf_array))

# %%
def bm25_weights(tokenized_corpus):
    bm25 = BM25Okapi(tokenized_corpus)
    average_idf = sum(bm25.idf.values()) / len(bm25.idf)

    # Convert tokenized_corpus to a list of NumPy arrays for faster operations
    tokenized_corpus_np = [np.array(doc) for doc in tokenized_corpus]
    
    bm25_weights = {}
    
    # Precompute document lengths and average document length
    doc_lengths = np.array([len(doc) for doc in tokenized_corpus_np])
    avgdl = doc_lengths.mean()

    for term in set(term for doc in tokenized_corpus for term in doc):
        idf = bm25.idf.get(term, average_idf)
        term_weights = []

        # Vectorize term frequency computation
        term_frequencies = np.array([np.sum(doc == term) for doc in tokenized_corpus_np])
        valid_docs = term_frequencies > 0  # Only consider documents where term frequency > 0

        if np.any(valid_docs):
            tf = term_frequencies[valid_docs]
            dl = doc_lengths[valid_docs]
            norm_tf = tf * (bm25.k1 + 1) / (tf + bm25.k1 * (1 - bm25.b + bm25.b * (dl / avgdl)))
            term_weights = idf * norm_tf

        bm25_weights[term] = np.pad(term_weights, (0, len(tokenized_corpus_np) - len(term_weights)), 'constant')

    return pd.DataFrame(bm25_weights)

# %%
def bert_weights(corpus):
    model=SentenceTransformer('bert-base-nli-mean-tokens')
    vectors=model.encode(corpus)
    weights=pd.DataFrame(cosine_similarity(vectors))
    return weights

# %%
def recommend_movie(df:pd.DataFrame, title_col:str, index: int, vector, n: int):
    """vector: cos_similarity_matrix"""
    similarities=vector.iloc[index].values
    sim_idxs=np.argsort(-similarities)[1:n+1] #indices based on desc similarities; skip the first movie since its what is originally selected
    movies=df[title_col].values
    similar_movies=movies[sim_idxs]
    return similar_movies

# %%
movie_summary='Summary'
norm_corp=normalized_corpus(df=new_df, descript_col=movie_summary,)
tfidf_matrix=tf_idf_features(df=new_df, normalized_corpus=norm_corp)
cosine_sim_matrix=vector_cosine_sim(tfidf_matrix)
cosine_sim_matrix.head()
# Out:
#       0         1         2      3      4      5         6      7      \
# 0  1.000000  0.018423  0.012557    0.0    0.0    0.0  0.000000    0.0
# 1  0.018423  1.000000  0.000000    0.0    0.0    0.0  0.000000    0.0
# 2  0.012557  0.000000  1.000000    0.0    0.0    0.0  0.000000    0.0
# 3  0.000000  0.000000  0.000000    1.0    0.0    0.0  0.000000    0.0
# 4  0.000000  0.000000  0.000000    0.0    1.0    0.0  0.060903    0.0
#
#       8      9      ...     26355     26356     26357     26358     26359  \
# 0  0.000000    0.0  ...  0.000000  0.017053  0.010103  0.000000  0.000000
# 1  0.000000    0.0  ...  0.000000  0.000000  0.000000  0.027681  0.000000
# 2  0.014331    0.0  ...  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000    0.0  ...  0.000000  0.000000  0.000000  0.014241  0.000000
# 4  0.009309    0.0  ...  0.034803  0.035403  0.039466  0.047332  0.054357
#
#       26360     26361     26362     26363     26364
# 0  0.000000  0.013713  0.000000  0.045604  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.004530
# 2  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.032324  0.018693  0.062598  0.000000  0.010428
#
# [5 rows x 26365 columns]

# %%
num_movies=5
reccs=recommend_movie(df=new_df, title_col=title, index=movie_idx, vector=cosine_sim_matrix, n=num_movies)
print(reccs)

#issue here is if the movie titles only contain the same title (further preprocesssing needed)
# Out:
# ['one piece' 'one piece' 'one piece' 'one piece' 'one piece']

# %%
new_df[new_df[title]=='one piece'].values
# Out:
# array([['one piece',
#         'One Piece. Follows the adventures of Monkey D. Luffy and his pirate crew in order to find the greatest treasure ever left by the legendary Pirate, Gold Roger. The famous mystery treasure named "One Piece".'],
#        ['one piece',
#         'One Piece. Luffy reflects on his past and how he came in possession of his Straw Hat.'],
#        ['one piece',
#         'One Piece. Luffy convinces Zoro to join her crew, but they must defeat Captain Morgan first. Meanwhile, Koby is accepted as a marine.'],
#        ...,
#        ['one piece',
#         'One Piece. Luffy and Katakuri both land simultaneous blows ending their battle with both of them on the ground. Pekoms helps Luffy by bringing Brulee to allow him to escape from the mirror world.'],
#        ['one piece',
#         "One Piece. Sanji and Luffy make it back to the sunny. The fire tank pirates make it to their destination but their ship gets destroyed by Big Mom. As the straw hats are surrounded Jinbie's old crew the Sun pirates help them."],
#        ['one piece',
#         'One Piece. Carrot tells Sanji the news about Pedro. Germa and the Sun pirates continue on fighting with the Big Mom Pirates to allow for the straw hats to escape. Pudding remembers her time with Sanji. Brulee tends to Katakuri.']],
#       dtype=object)

# %%
#BM25 method requires documents in the form of tokens
bm_25_norm_corp=normalized_corpus(df=new_df, descript_col=movie_summary, tokens=True) 
bm_25_norm_corp[:3]
bm25_wts=bm25_weights(bm_25_norm_corp)
bm25_wts.head()

# %%
bm25_reccs=recommend_movie(df=new_df, title_col=title, index=movie_idx, vector=bm25_wts_df, n=num_movies)
print(bm25_reccs)

# %%
#BERT method (Takes a lot of CPU! Reduced new_df to 10k to test it out)
movie_summary='Summary'
norm_corp=normalized_corpus(df=new_df.iloc[:10000], descript_col=movie_summary,)
bert_wts=bert_weights(norm_corp)

# %%
bert_reccs=recommend_movie(df=new_df, title_col=title, index=movie_idx, vector=bert_wts, n=num_movies)
print(bert_reccs[:2])
# Out:
# ['one piece: baron omatsuri and the secret island'
#  'lupin iii: princess of the breeze']
